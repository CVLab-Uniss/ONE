# %%
#!pip install opencv-python
#!pip install ultralytics
#!pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.3-py3-none-any.whl (139 kB)
# Collecting jupyterlab-widgets~=3.0.11
#   Downloading jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipywidgets) (8.4.0)
# Collecting widgetsnbextension~=4.0.11
#   Downloading widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
# Collecting comm>=0.1.3
#   Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: pickleshare in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.3.0)
# Requirement already satisfied: backcall in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.12.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.30)
# Requirement already satisfied: colorama in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.5)
# Requirement already satisfied: matplotlib-inline in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: six in c:\users\andrea\anaconda3\envs\test\lib\site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, comm, ipywidgets
# Successfully installed comm-0.2.2 ipywidgets-8.1.3 jupyterlab-widgets-3.0.11 widgetsnbextension-4.0.11

# %%
from ultralytics import YOLO
import numpy as np
import cv2

#https://github.com/ultralytics/ultralytics
#https://docs.ultralytics.com/modes/predict/#inference-arguments

'''
  2  587 894 Auto ferma in corsia di emergenza
  9    0 287 Alta densità di traffico? Cambio prospettiva
 11    0 888 Coda
 14  475 600 Coda. Cambio prospettiva.
 33    0 90  Auto ferma in corsia emergenza
 33  165 894 Auto si ferma in corsia di ingresso
 35  106 185 Camion fermo in basso a sinistra
 49  422 894 Auto si ferma in corsia emergenza
 51  431 891 Auto si ferma in corsia emergenza. Cambio di inquadratura
 63   87 853 Camion si ferma in corsia di emer. Nel finale cambia inquadratura
 72   87 894 Auto si ferma in corsia emergenza
 73  155 894 Camion si ferma in corsia di emergenza
 74  293 894 Auto si ferma in corsia emergenza 
 83  540 892 Auto si ferma in corsia emergenza. Nevica
 91  602 900 Auto fa testa coda.
 93    0 892 Auto ferma in corsia emergenza
 95   38 894 Incidente. Macchina si ribalta.
 97    0 890 Auto ferme in corsia emergenza
 '''

model = YOLO('yolov8m.pt')

#lista delle classi
#print(model.names)

pth = "aic21-track4-train-data/"
fname = "33.mp4" #Anomalia: Auto si ferma in corsia di ingresso
#fname = "34.mp4" #Nessuna anomalia
#fname = "49.mp4" #Anomalia: Auto si ferma in corsia di emergenza
#fname = "50.mp4" #Nessuna anomalia

frameSlot = 360 #numero di frame utilizzati per il calcolo del background
timeSlot = 3600 #numero di frame di intervallo fra un calcolo bg e l'altro
counter = timeSlot

cap = cv2.VideoCapture(pth+fname)

# Dimensioni dei frame (altezza e larghezza)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Numero totale di frame nel video
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Crea una matrice tridimensionale vuota per contenere i frame
#frames = np.empty((numFrame, frame_height, frame_width, 3), dtype=np.uint8)
frames = np.empty((frameSlot, frame_height, frame_width), dtype=np.uint8)

while(cap.isOpened()):
    ret, frame = cap.read()
    if not ret:
        print(f"Fine del file.")
        break 
          
    if (counter%timeSlot == 0):                
        for i in range(frameSlot):                       
            ret, frame = cap.read()   
            
            if not ret:
                print(f"Errore nella lettura del frame {i}.")
                break                        
                
            frames[i] = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            
        median_frame = np.median(frames, axis=0).astype(np.uint8)
        counter = 0
        
        cv2.imwrite('image.jpg', median_frame)      
        #cv2.imshow('Median Frame', median_frame)
        #cv2.waitKey(0)
        #cv2.destroyAllWindows()
        
        # list of Results objects
        results = model('image.jpg', 
                        imgsz=[frame_height, frame_width], #provato ingrandire di fattore 2 sembra meglio su 33.mp4
                        augment=True, 
                        retina_masks=True, 
                        device=0,
                        conf=0.35,
                        classes = [0, 1, 2, 3, 5, 6, 7, 13, 14, 15, 16, 17, 18, 19, 20, 21, 23],
                        show=False,
                        save=False,
                        save_txt=False)  
        
        res = results[0].boxes.cls.cpu().numpy()
        if (res.size > 0):
            print("Detected object:")
            for t in range(res.size):
                label = int(res[t])
                print(model.names[label])
        else:
            print("No detected object!")
                            
        #cv2.waitKey(0)
        
    counter = counter + 1
    
# Rilascia la risorsa del video
cap.release()

#cv2.imshow('Median Frame', median_frame)
#cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# %run AnomalyDect.py
# Out:
# WARNING ⚠️ imgsz=[410, 800] must be multiple of max stride 32, updating to [416, 800]
# image 1/1 /home/visionlab/CondaWS/ONE/Demo_AD/image.jpg: 416x800 1 car, 11.0ms
# Speed: 0.6ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 800)
# Detected object:
# car
#
# WARNING ⚠️ imgsz=[410, 800] must be multiple of max stride 32, updating to [416, 800]
# image 1/1 /home/visionlab/CondaWS/ONE/Demo_AD/image.jpg: 416x800 (no detections), 10.2ms
# Speed: 0.6ms preprocess, 10.2ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 800)
# No detected object!
#
# WARNING ⚠️ imgsz=[410, 800] must be multiple of max stride 32, updating to [416, 800]
# image 1/1 /home/visionlab/CondaWS/ONE/Demo_AD/image.jpg: 416x800 1 car, 10.2ms
# Speed: 0.6ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 800)
# Detected object:
# car
#
# WARNING ⚠️ imgsz=[410, 800] must be multiple of max stride 32, updating to [416, 800]
# image 1/1 /home/visionlab/CondaWS/ONE/Demo_AD/image.jpg: 416x800 1 car, 11.5ms
# Speed: 0.6ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 800)
# Detected object:
# car
#
# WARNING ⚠️ imgsz=[410, 800] must be multiple of max stride 32, updating to [416, 800]
# image 1/1 /home/visionlab/CondaWS/ONE/Demo_AD/image.jpg: 416x800 3 cars, 10.3ms
# Speed: 0.6ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 800)
# Detected object:
# car
# car
# car
#
# WARNING ⚠️ imgsz=[410, 800] must be multiple of max stride 32, updating to [416, 800]
# image 1/1 /home/visionlab/CondaWS/ONE/Demo_AD/image.jpg: 416x800 3 cars, 10.1ms
# Speed: 0.6ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 800)
# Detected object:
# car
# car
# car
#
# WARNING ⚠️ imgsz=[410, 800] must be multiple of max stride 32, updating to [416, 800]
# image 1/1 /home/visionlab/CondaWS/ONE/Demo_AD/image.jpg: 416x800 2 cars, 11.2ms
# Speed: 0.6ms preprocess, 11.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 800)
# Detected object:
# car
# car
# Fine del file.
