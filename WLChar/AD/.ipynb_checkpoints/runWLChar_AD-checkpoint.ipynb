# %%
# %run WLChar_AD_API.py
# Out:
# Local device in use: cpu
# Object detection model in use: yolo11m.pt
#
#
# ********** START ANOMALY DETECTION TASK **********
# Starting acquisition for background estimation
# Acquiring 360 frames from camera (12 seconds): 100%|███████████████████████████████████████████████████████████████████████████| 360/360 [00:12<00:00, 29.80it/s]
# New object detected: car
# Status code: 200
# Response body: {"message":"Anomaly logging running"}
#
# New object detected: car
# Status code: 200
# Response body: {"message":"Anomaly logging running"}
#
# Starting acquisition for background estimation
# Acquiring 360 frames from camera (12 seconds): 100%|███████████████████████████████████████████████████████████████████████████| 360/360 [00:11<00:00, 30.12it/s]
# No object detected
# Starting acquisition for background estimation
# Acquiring 360 frames from camera (12 seconds):  78%|██████████████████████████████████████████████████████████▊                | 282/360 [00:09<00:02, 29.93it/s]
# ...

# %%
# %run WLChar_AD.py
# Out:
# Video selezionato: 49.mp4
# Dispositivo in uso: cpu
# Acquiring 360 frames from camera (12 seconds): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 360/360 [00:12<00:00, 29.75it/s]
# 2475
# Detected object:
# None
# Acquiring 3600 frames from camera (119.37142896652222 seconds): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3600/3600 [02:00<00:00, 29.94it/s]
