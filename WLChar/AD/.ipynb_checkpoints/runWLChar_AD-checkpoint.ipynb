# %%
# %run WLChar_AD_API.py
# Out:
# Local device in use: cpu
# Object detection model in use: yolo11m.pt
#
#
# Starting acquisition for background estimation
# Acquiring 360 frames from camera (12 seconds): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 360/360 [00:12<00:00, 29.77it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/CondaWS/ONE/WLChar/AD/WLChar_AD_API.py:176
#     173     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     174     frames[i] = gray
# --> 176 # Calcolo della mediana dei frame
#     177 median_frame = np.median(frames, axis=0).astype(np.uint8)
#     178 im = Image.fromarray(median_frame)
#
# KeyboardInterrupt:

# %%
# %run WLChar_AD.py
# Out:
# Video selezionato: 49.mp4
# Dispositivo in uso: cpu
# Acquiring 360 frames from camera (12 seconds): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 360/360 [00:12<00:00, 29.75it/s]
# 2475
# Detected object:
# None
# Acquiring 3600 frames from camera (119.37142896652222 seconds): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3600/3600 [02:00<00:00, 29.94it/s]
