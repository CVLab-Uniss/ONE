# %%
# !pip install waitress flask

# %%
# %run WLChar_AD_API_v2.py
# Out:
# Local device in use: cpu
# Object detection model in use: yolo11m.pt
#
#
# ********** START ANOMALY DETECTION TASK **********
# Info about slave node received from Master node!
#  end_point= slave-gateway-oristano-01.128.203.65.69.nip.io, token=edge-temporary-token
# Starting acquisition for background estimation
# Acquiring 360 frames from camera (12 seconds):  54%|█████████████████████████████████████████████████████                                             | 195/360 [00:06<00:05, 29.71it/s]

# %%
# %run WLChar_AD_iterative.py

# %%
# %run WLChar_AD_iterative_performance.py
# Out:
# Dispositivo in uso: cuda
# frame_slot = 120
# ...
# Analisi 6.mp4:   0%|          | 0/26789 [00:00<?, ?frame/s]
# Errore nella lettura del frame 26789
# Analisi 10.mp4:   0%|          | 0/26868 [00:00<?, ?frame/s]
# Errore nella lettura del frame 26868
# Analisi 13.mp4:   0%|          | 0/26580 [00:00<?, ?frame/s]
# Errore nella lettura del frame 26580
# Analisi 92.mp4:   0%|          | 0/26668 [00:00<?, ?frame/s]
# Errore nella lettura del frame 26668
# Analisi 4.mp4:   0%|          | 0/26865 [00:00<?, ?frame/s]
# Errore nella lettura del frame 26865
# Analisi 66.mp4:   0%|          | 0/21017 [00:00<?, ?frame/s]
# Errore nella lettura del frame 21017
# Analisi 40.mp4:   0%|          | 0/26782 [00:00<?, ?frame/s]
# Errore nella lettura del frame 26782
# Analisi 3.mp4:   0%|          | 0/26766 [00:00<?, ?frame/s]
# Errore nella lettura del frame 26766
# Analisi 69.mp4:   0%|          | 0/26728 [00:00<?, ?frame/s]
# Errore nella lettura del frame 26728
# ...
