# %%
# %run WLChar_AD_API.py
# Out:
# Dispositivo in uso: cpu
# Video selezionato: 50.mp4
# Acquiring 360 frames from camera (12 seconds): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 360/360 [00:12<00:00, 29.80it/s]
# Detected object:
# None
# Video selezionato: 49.mp4
# Acquiring 360 frames from camera (12 seconds):  55%|█████████████████████████████████████████████████████████████████████████████████████████                                                                         | 198/360 [00:06<00:05, 29.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/CondaWS/ONE/WLChar/AD/WLChar_AD_API.py:143
#     141 print(f"Video selezionato: {video_name}")
#     142 # Apre il video selezionato
# --> 143 cap = cv2.VideoCapture(video_path)
#     144 if not cap.isOpened():
# ...

# %%
# %run WLChar_AD.py
# Out:
# Video selezionato: 50.mp4
# Dispositivo in uso: cpu
# Acquiring 360 frames from camera (12 seconds): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 360/360 [00:12<00:00, 29.81it/s]
# Detected object:
# None
# Acquiring 3600 frames from camera (119.31950855255127 seconds):  29%|█████████████████████████████████████████▎                                                                                                     | 1039/3600 [00:34<01:25, 29.94it/s]
