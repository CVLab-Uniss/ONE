# %%
# !pip install waitress Flask

# %%
# %run WLChar_ReID.py

# %%
# %run WLChar_ReID_API.py
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at '/home/visionlab/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Local device in use: cpu
# Object detection model in use: yolo11m.pt
# Features extraction model in use: dinov2_vits14
#
#
# ********** START RE-IDENTIFICATION TASK **********
# Using cache found in /home/visionlab/.cache/torch/hub/facebookresearch_dinov2_main
# /home/visionlab/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# ...
