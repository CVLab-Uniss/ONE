# %%
# %run Demo_ReID.py
# Out:
# Using cache found in /home/visionlab/.cache/torch/hub/facebookresearch_dinov2_main
# DEVICE used:  cuda
# Query image (vehicle id:  00256 )
# <PIL.Image.Image image mode=RGB size=250x250>
# Query vehicle NOT found in camera num.  2
# Query vehicle NOT found in camera num.  30
# Query vehicle NOT found in camera num.  39
# Query vehicle NOT found in camera num.  102
# Query vehicle NOT found in camera num.  3
# Query vehicle NOT found in camera num.  172
# Query vehicle NOT found in camera num.  23
# Query vehicle NOT found in camera num.  137
# Query vehicle NOT found in camera num.  79
# Query vehicle NOT found in camera num.  34
# Query vehicle NOT found in camera num.  78
# Query vehicle found in camera num.  41  (vehicle id: 01296 )
# <PIL.Image.Image image mode=RGB size=250x250>
# Query vehicle found in camera num.  51  (vehicle id: 00256 )
# <PIL.Image.Image image mode=RGB size=250x250>
# Query vehicle NOT found in camera num.  111
# Query vehicle NOT found in camera num.  110
# ...

# %%
import torch
torch.zeros(1).cuda()
# Out:
# tensor([0.], device='cuda:0')

# %%
# !conda list | grep cuda
# Out:
# cuda-cudart               11.8.89                       0    nvidia
# nvidia-cuda-cupti-cu12    12.1.105                 pypi_0    pypi
# nvidia-cuda-nvrtc-cu12    12.1.105                 pypi_0    pypi
# nvidia-cuda-runtime-cu12  12.1.105                 pypi_0    pypi

# %%
# !conda list pytorch
# Out:
# # packages in environment at /home/visionlab/anaconda3/envs/ONE_finetuning:
# #
# # Name                    Version                   Build  Channel
