# %%
# !pip install waitress Flask

# %%
# %run WLChar_ReID.py

# %%
# %run WLChar_ReID_API.py
# Out:
# Local device in use: cuda
# Object detection model in use: yolo11m.pt
# Features extraction model in use: dinov2_vits14
# Using cache found in /home/visionlab/.cache/torch/hub/facebookresearch_dinov2_main
# Server ready!
#
# Ultralytics 8.3.31 🚀 Python-3.11.9 torch-2.3.1+cu121
# ERROR:WLChar_ReID_API:Exception on /run_reid [POST]
# Traceback (most recent call last):
#   File "/home/visionlab/anaconda3/envs/ONE_finetuning/lib/python3.11/site-packages/flask/app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/visionlab/anaconda3/envs/ONE_finetuning/lib/python3.11/site-packages/flask/app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/visionlab/anaconda3/envs/ONE_finetuning/lib/python3.11/site-packages/flask/app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
# ...
